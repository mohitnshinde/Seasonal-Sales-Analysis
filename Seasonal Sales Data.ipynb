# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # visualiaizing data 
# %matplotlib inline
import seaborn as sns 
#imports libraries

# %%
df = pd.read_csv(r'C:\Users\mohishin\Desktop/Seasonal Sales Data.csv', encoding = 'unicode_escape')
# imports data CSV file

# %%
df.shape # tells the rows and columns in the datab
# Out:
# (11251, 13)

# %%
df.head(10) #gives the 5 data where we can obtain more by placing it in the round brackets
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.info() # for checking all the columns to ensure are there any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df) # for checking the null values where false means there are no null vlauesbbb
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum() # sums all the null values or  total number of missing values (NaN) in each column of a pandas DataFrame (df).
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace = True) # It is used to remove any rows in a DataFrame (df) that contain missing (NaN) values.

# %%
df.shape # returs of no of rows and no of columns
# Out:
# (11251, 13)

# %%
df['Amount'] = df['Amount'].astype ('int')

# %%
df["Amount"] = df["Amount"].fillna(0).astype("int") #replace all NaN values with 0 and then convert the column to integers.

# %%
df['Amount'].dtypes  # it is used to check the data type
# Out:
# dtype('int32')

# %%
df.columns # shows all columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status' : 'shaadi'}) # it is used to rename and till the time we are not using the inplace=true it will not be stored or the values won't get changed
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.describe() # it is used to generate summary statistics of the numeric columns in a DataFrame (df).
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9443.527598
# std    1.716125e+03     12.754122        0.493632      1.115047   5228.683337
# min    1.000001e+06     12.000000        0.000000      1.000000      0.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5440.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age', 'Orders', 'Amount']].describe() #Specifically it is used for the reqd columns
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      35.421207      2.489290   9443.527598
# std       12.754122      1.115047   5228.683337
# min       12.000000      1.000000      0.000000
# 25%       27.000000      1.500000   5440.000000
# 50%       33.000000      2.000000   8108.000000
# 75%       43.000000      3.000000  12671.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Gender

# %%
df.columns
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax = sns.countplot(x= 'Gender', data = df)

# %%
# plotting a bar chart for knowing the count of male and female
ax = sns.countplot(x = 'Gender',data = df, palette = 'pastel')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\mohishin\AppData\Local\Temp\ipykernel_716\3825786771.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = 'Gender',data = df, palette = 'pastel')

# %%
# plotting a bar chart for knowing spend by male and female
df.groupby(['Gender'], as index = False) ['Amount'].sum().sort_values(by = 'Amount', ascending = False
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
#plotting a bar chart for amount spend by male and female
sales_gen = df.groupby(['Gender'], as_index = False) ['Amount'].sum().sort_values(by = 'Amount', ascending = False)

sns.barplot(x = 'Gender', y = 'Amount', data = sales_gen, palette="pastel", hue='Gender') # palette is used for colours

plt.show()

# %% [markdown]
# Age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
#Total Amount vs Age group
sales_age = df.groupby(['Age Group'], as_index = False)['Amount'].sum().sort_values(by= 'Amount', ascending = False)

# %%
#Total amount vs Age group
df.groupby(['Age Group'], as_index = False)['Amount'].sum().sort_values(by= 'Amount', ascending = False)

sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age, palette = 'pastel')

plt.show()
# Out:
# C:\Users\mohishin\AppData\Local\Temp\ipykernel_716\1272219191.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age, palette = 'pastel')

# %% [markdown]
# State

# %%
# total no of order from 10 states
sales_state= df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by='Orders', ascending = False).head(10)

sns.set(rc={'figure.figsize':(16,5)})
sns.barplot(x = 'State', y = 'Orders', data = sales_state)
plt.show()

# %%
# total amount / sales from top 10 states
sales_state = df.groupby(['State'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending = False).head(10)

sns.set(rc= {'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x= 'State', y='Amount' , palette = 'pastel')

plt.show()
# Out:
# C:\Users\mohishin\AppData\Local\Temp\ipykernel_716\1710675748.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x= 'State', y='Amount' , palette = 'pastel')

# %% [markdown]
# Marital Status

# %%
ax= sns.countplot(data=df, x= 'Marital_Status')

sns.set(rc= {'figure.figsize':(5,5)})
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index = False)['Amount'].sum().sort_values(by= 'Amount', ascending = False)

sns.set(rc= {'figure.figsize':(5,5)})
sns.barplot(data = sales_state,x = 'Marital_Status', y = 'Amount', hue = 'Gender')
plt.show()

# %% [markdown]
# Occupation

# %%
#Total count vs Sector
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation', palette = 'pastel')


for bars in ax.containers:
    ax.bar_label(bars)
plt.show()
# Out:
# C:\Users\mohishin\AppData\Local\Temp\ipykernel_716\736573261.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Occupation', palette = 'pastel')

# %%
# Total amount vs sector
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
plt.show()

# %% [markdown]
# Product Category

# %%
Count vs Product category
sns.set(rc={'figure.figsize':(27,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
# Product category vs Total Amount
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
plt.show()

# %%
# Product category vs orders
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
plt.show()

# %%
# top 10 most sold products 

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Married women of age group 26-35 yrs are mostly from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation who are more likely to buy products from Food, Clothing and Electronics category.
